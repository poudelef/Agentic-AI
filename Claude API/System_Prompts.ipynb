# %%
# Create API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-opus-4-1-20250805"

# Load environment variables from .env file
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
def add_user_message(messages, text):
    user_message= {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)   

def chat(messages, system = None, temperature = 1.0):   
    prompt = {
        "model":model,
        "max_tokens":1000,
        "messages": messages,
        "temperature": temperature,
    } 

    # We Can't pass system promot of none
    if system:
        prompt["system"]= system
    
    messages = client.messages.create(**prompt)
    
    return messages.content[0].text

# %%
system = """
    You are a math tutor. You will help solving the answer by 
    showing the way or doing similar problem but you don' give the answer that easily.
    
    """ 

messages = []
add_user_message(messages, "How to solve 5x + 2 = 12")
chat(messages,system=system)
# Out:
# 'Great question! Let me guide you through solving this linear equation step by step.\n\nFirst, let\'s understand what we\'re trying to do: we want to find the value of x that makes this equation true.\n\n**The key principle:** Whatever operation we do to one side of the equation, we must do to the other side to keep it balanced.\n\nLet\'s start:\n- Look at the equation: 5x + 2 = 12\n- What\'s making it complicated? We have "+2" added to our 5x term.\n\n**First step:** How can we get rid of that "+2" on the left side? What operation would cancel it out?\n\nThink about it and tell me what you would do first. \n\n(Hint: If something is added, what\'s the opposite operation?)'

# %%
system = """
You are a computer programer and you generate code that is clean and easy to understand and effective. 
You will take space new line and wrtie code that is very clean with less symboles.
"""
messages = []
add_user_message(messages, "Give me a movie Idea")
chat(messages, temperature=0.0)
# Out:
# '## "The Last Bookmark"\n\n**Genre:** Sci-fi Mystery/Thriller\n\n**Logline:** A librarian discovers that certain books in her library are actually portals to the final moments of extinct civilizations across the universe—and someone is systematically destroying them to hide evidence of what really caused these worlds to end.\n\n**The Hook:** \nMaya, a small-town librarian dealing with budget cuts and the threat of her library closing, notices that whenever she places her grandmother\'s strange metal bookmark in certain old books, she\'s transported to alien worlds in their final days. She witnesses advanced civilizations in their last 24 hours before mysterious catastrophes.\n\nAs she investigates, she realizes:\n- The same warning symbols appear in each dying world\n- Someone has been removing these specific books from libraries worldwide\n- Her grandmother was part of a secret society of "Readers" who guard this knowledge\n- Earth\'s book might be next\n\n**The Twist:** \nThe catas
# ...

# %%
system = """
You are a computer programer and you generate code that is clean and easy to understand and effective. 
You will take space new line and wrtie code that is very clean with less symboles.
"""
messages = []
add_user_message(messages, "Wrtie a python function that checks a string for duplicate characters.")
chat(messages, system)

# %% [markdown]
# # Response Streem

# %%
messages = []
add_assistant_message(messages, "What is web socket?")

Stream = client.messages.create(
    model=model,
    max_tokens= 500,
    messages= messages,
    stream = True

)

for event in Stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_01TauZQhtr2CS65K85N3L71Y', container=None, content=[], model='claude-opus-4-1-20250805', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=21, output_tokens=3, server_tool_use=None, service_tier='standard')), type='message_start')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=21, output_tokens=3, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
messages = []
add_user_message(messages, "What is web socket")

with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages
) as stream:
    for text in stream.text_stream:
        # print(text,end="")
        pass

stream.get_final_message()
# Out:
# ParsedMessage(id='msg_01DT516jSU96Vvo4PnmfBjfn', container=None, content=[ParsedTextBlock(citations=None, text='I believe you\'re asking about **WebSocket** (not "we socket"). WebSocket is a communication protocol that enables two-way, real-time communication between a client (typically a web browser) and a server over a single TCP connection.\n\n## Key Features:\n\n### **Full-Duplex Communication**\n- Both client and server can send messages to each other simultaneously\n- No need for polling or repeated HTTP requests\n\n### **Persistent Connection**\n- Maintains an open connection between client and server\n- Reduces overhead compared to traditional HTTP request/response cycles\n\n### **Real-Time Data Transfer**\n- Low latency communication\n- Ideal for applications requiring instant updates\n\n## How It Works:\n\n1. **Handshake**: Starts as an HTTP request that "upgrades" to WebSocket protocol\n2. **Connection Established**: Once upgraded, both parties can exchange data freely\n3.
# ...

# %% [markdown]
# # Structured Data

# %%
def add_user_message(messages, text):
    user_message= {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)   

def chat(messages, system = None, temperature = 1.0,stop_sequences= None):   
    prompt = {
        "model":model,
        "max_tokens":1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences":  stop_sequences
    } 

    # We Can't pass system promot of none
    if system:
        prompt["system"]= system
    
    messages = client.messages.create(**prompt)
    
    return messages.content[0].text

# %%
messages = []
add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")
text = chat(messages, stop_sequences=["```"])

# %%
text
# Out:
# '\n{\n  "Name": "my-event-rule",\n  "EventPattern": {\n    "source": ["aws.ec2"],\n    "detail-type": ["EC2 Instance State-change Notification"],\n    "detail": {\n      "state": ["terminated"]\n    }\n  },\n  "State": "ENABLED",\n  "Targets": [\n    {\n      "Arn": "arn:aws:sns:us-east-1:123456789012:my-topic",\n      "Id": "1"\n    }\n  ]\n}\n'

# %%
import json
json.loads(text.strip())
# Out:
# {'Name': 'my-event-rule',
#  'EventPattern': {'source': ['aws.ec2'],
#   'detail-type': ['EC2 Instance State-change Notification'],
#   'detail': {'state': ['terminated']}},
#  'State': 'ENABLED',
#  'Targets': [{'Arn': 'arn:aws:sns:us-east-1:123456789012:my-topic',
#    'Id': '1'}]}

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short.
"""

add_user_message(messages, prompt)

text = chat(messages)
text.strip()
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File c:\Users\sambh\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\sambh\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\sambh\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...
